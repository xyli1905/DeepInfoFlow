# %%
from __future__ import print_function
# %load_ext autoreload
# %autoreload 2
import os, pickle
from collections import defaultdict, OrderedDict

import numpy as np
import keras.backend as K

import kde
import simplebinmi

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
sns.set_style('darkgrid')

import utils

# load data network was trained on
trn, tst = utils.get_IB_data('2017_12_21_16_51_3_275766')
# trn, tst = utils.get_mnist()

# calc MI for train and test. Save_activations must have been run with cfg['FULL_MI'] = True
FULL_MI = True

# Which measure to plot
infoplane_measure = 'upper'
# infoplane_measure = 'bin'

DO_SAVE        = True    # Whether to save plots or just show them
DO_LOWER       = (infoplane_measure == 'lower')   # Whether to compute lower bounds also
DO_BINNED      = (infoplane_measure == 'bin')     # Whether to compute MI estimates based on binning

MAX_EPOCHS = 10000      # Max number of epoch for which to compute mutual information measure
NUM_LABELS = 2
# MAX_EPOCHS = 1000
COLORBAR_MAX_EPOCHS = 10000

# Directories from which to load saved layer activity
# ARCH = '1024-20-20-20'
ARCH = '12-10-7-5-4-3-2'
#ARCH = '20-20-20-20-20-20'
#ARCH = '32-28-24-20-16-12'
#ARCH = '32-28-24-20-16-12-8-8'
DIR_TEMPLATE = '%%s_%s'%ARCH

# Functions to return upper and lower bounds on entropy of layer activity
noise_variance = 1e-3                    # Added Gaussian noise variance
binsize = 0.07                           # size of bins for binning method
Klayer_activity = K.placeholder(ndim=2)  # Keras placeholder 
entropy_func_upper = K.function([Klayer_activity,], [kde.entropy_estimator_kl(Klayer_activity, noise_variance),])
entropy_func_lower = K.function([Klayer_activity,], [kde.entropy_estimator_bd(Klayer_activity, noise_variance),])

# nats to bits conversion factor
nats2bits = 1.0/np.log(2) 

# Save indexes of tests data for each of the output classes
saved_labelixs = {}

y = tst.y
Y = tst.Y
if FULL_MI:
    full = utils.construct_full_dataset(trn,tst)
    y = full.y
    Y = full.Y

for i in range(NUM_LABELS):
    saved_labelixs[i] = y == i

labelprobs = np.mean(Y, axis=0)
# Out:
# Using TensorFlow backend.

# %%
PLOT_LAYERS    = None     # Which layers to plot.  If None, all saved layers are plotted 

# Data structure used to store results
measures = OrderedDict()
measures['tanh'] = {}
measures['relu'] = {}
# measures['softsign'] = {}
# measures['softplus'] = {}

# %% [markdown]
# Compute MI measures
# -----

# %%
for activation in measures.keys():
    cur_dir = 'rawdata/' + DIR_TEMPLATE % activation
    if not os.path.exists(cur_dir):
        print("Directory %s not found" % cur_dir)
        continue
        
    # Load files saved during each epoch, and compute MI measures of the activity in that epoch
    print('*** Doing %s ***' % cur_dir)
    for epochfile in sorted(os.listdir(cur_dir)):
        if not epochfile.startswith('epoch'):
            continue
            
        fname = cur_dir + "/" + epochfile
        with open(fname, 'rb') as f:
            d = pickle.load(f)

        epoch = d['epoch']
        if epoch in measures[activation]: # Skip this epoch if its already been processed
            continue                      # this is a trick to allow us to rerun this cell multiple times)
            
        if epoch > MAX_EPOCHS:
            continue

        print("Doing", fname)
        
        num_layers = len(d['data']['activity_tst'])

        if PLOT_LAYERS is None:
            PLOT_LAYERS = []
            for lndx in range(num_layers):
                #if d['data']['activity_tst'][lndx].shape[1] < 200 and lndx != num_layers - 1:
                PLOT_LAYERS.append(lndx)
                
        cepochdata = defaultdict(list)
        for lndx in range(num_layers):
            activity = d['data']['activity_tst'][lndx]

            # Compute marginal entropies
            h_upper = entropy_func_upper([activity,])[0]
            if DO_LOWER:
                h_lower = entropy_func_lower([activity,])[0]
                
            # Layer activity given input. This is simply the entropy of the Gaussian noise
            hM_given_X = kde.kde_condentropy(activity, noise_variance)

            # Compute conditional entropies of layer activity given output
            hM_given_Y_upper=0.
            for i in range(NUM_LABELS):
                hcond_upper = entropy_func_upper([activity[saved_labelixs[i],:],])[0]
                hM_given_Y_upper += labelprobs[i] * hcond_upper
                
            if DO_LOWER:
                hM_given_Y_lower=0.
                for i in range(NUM_LABELS):
                    hcond_lower = entropy_func_lower([activity[saved_labelixs[i],:],])[0]
                    hM_given_Y_lower += labelprobs[i] * hcond_lower
                
            cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
            cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
            cepochdata['H_M_upper'  ].append( nats2bits * h_upper )

            pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1])
            if DO_LOWER:  # Compute lower bounds
                cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

            if DO_BINNED: # Compute binned estimates
                binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, binsize)
                cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                cepochdata['MI_YM_bin'].append( nats2bits * binym )
                pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])
                        
            print('- Layer %d %s' % (lndx, pstr) )

        measures[activation][epoch] = cepochdata
# Out:
# *** Doing rawdata/tanh_12-10-7-5-4-3-2 ***
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000000
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.979, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.628, MI(Y;M)=0.587
# - Layer 4 upper: MI(X;M)=7.943, MI(Y;M)=0.187
# - Layer 5 upper: MI(X;M)=6.423, MI(Y;M)=0.090
# - Layer 6 upper: MI(X;M)=5.450, MI(Y;M)=0.050
# - Layer 7 upper: MI(X;M)=1.084, MI(Y;M)=0.006
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000001
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.969, MI(Y;M)=0.990
# - Layer 3 upper: MI(X;M)=10.493, MI(Y;M)=0.570
# - Layer 4 upper: MI(X;M)=7.795, MI(Y;M)=0.197
# - Layer 5 upper: MI(X;M)=6.282, MI(Y;M)=0.107
# - Layer 6 upper: MI(X;M)=5.352, MI(Y;M)=0.055
# - Layer 7 upper: MI(X;M)=1.059, MI(Y;M)=0.011
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000002
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.952, MI(Y;M)=0.984
# - Layer 3 upper: MI(X;M)=10.309, MI(Y;M)=0.543
# - Layer 4 upper: MI(X;M)=7.641, MI(Y;M)=0.215
# - Layer 5 upper: MI(X;M)=6.156, MI(Y;M)=0.132
# - Layer 6 upper: MI(X;M)=5.284, MI(Y;M)=0.070
# - Layer 7 upper: MI(X;M)=1.066, MI(Y;M)=0.026
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000003
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.933, MI(Y;M)=0.979
# - Layer 3 upper: MI(X;M)=10.129, MI(Y;M)=0.519
# - Layer 4 upper: MI(X;M)=7.551, MI(Y;M)=0.231
# - Layer 5 upper: MI(X;M)=6.124, MI(Y;M)=0.152
# - Layer 6 upper: MI(X;M)=5.330, MI(Y;M)=0.090
# - Layer 7 upper: MI(X;M)=1.123, MI(Y;M)=0.046
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000004
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.915, MI(Y;M)=0.975
# - Layer 3 upper: MI(X;M)=9.989, MI(Y;M)=0.501
# - Layer 4 upper: MI(X;M)=7.523, MI(Y;M)=0.245
# - Layer 5 upper: MI(X;M)=6.165, MI(Y;M)=0.170
# - Layer 6 upper: MI(X;M)=5.445, MI(Y;M)=0.112
# - Layer 7 upper: MI(X;M)=1.216, MI(Y;M)=0.067
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000005
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.897, MI(Y;M)=0.971
# - Layer 3 upper: MI(X;M)=9.877, MI(Y;M)=0.490
# - Layer 4 upper: MI(X;M)=7.513, MI(Y;M)=0.255
# - Layer 5 upper: MI(X;M)=6.222, MI(Y;M)=0.186
# - Layer 6 upper: MI(X;M)=5.569, MI(Y;M)=0.137
# - Layer 7 upper: MI(X;M)=1.330, MI(Y;M)=0.091
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000006
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.880, MI(Y;M)=0.967
# - Layer 3 upper: MI(X;M)=9.791, MI(Y;M)=0.488
# - Layer 4 upper: MI(X;M)=7.530, MI(Y;M)=0.267
# - Layer 5 upper: MI(X;M)=6.296, MI(Y;M)=0.203
# - Layer 6 upper: MI(X;M)=5.704, MI(Y;M)=0.162
# - Layer 7 upper: MI(X;M)=1.471, MI(Y;M)=0.115
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000007
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.866, MI(Y;M)=0.964
# - Layer 3 upper: MI(X;M)=9.735, MI(Y;M)=0.492
# - Layer 4 upper: MI(X;M)=7.569, MI(Y;M)=0.280
# - Layer 5 upper: MI(X;M)=6.403, MI(Y;M)=0.221
# - Layer 6 upper: MI(X;M)=5.880, MI(Y;M)=0.187
# - Layer 7 upper: MI(X;M)=1.628, MI(Y;M)=0.140
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000008
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.862, MI(Y;M)=0.964
# - Layer 3 upper: MI(X;M)=9.721, MI(Y;M)=0.501
# - Layer 4 upper: MI(X;M)=7.634, MI(Y;M)=0.293
# - Layer 5 upper: MI(X;M)=6.527, MI(Y;M)=0.240
# - Layer 6 upper: MI(X;M)=6.064, MI(Y;M)=0.212
# - Layer 7 upper: MI(X;M)=1.801, MI(Y;M)=0.165
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000009
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.856, MI(Y;M)=0.965
# - Layer 3 upper: MI(X;M)=9.696, MI(Y;M)=0.509
# - Layer 4 upper: MI(X;M)=7.686, MI(Y;M)=0.310
# - Layer 5 upper: MI(X;M)=6.620, MI(Y;M)=0.265
# - Layer 6 upper: MI(X;M)=6.207, MI(Y;M)=0.242
# - Layer 7 upper: MI(X;M)=1.978, MI(Y;M)=0.194
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000010
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.851, MI(Y;M)=0.967
# - Layer 3 upper: MI(X;M)=9.683, MI(Y;M)=0.522
# - Layer 4 upper: MI(X;M)=7.741, MI(Y;M)=0.336
# - Layer 5 upper: MI(X;M)=6.722, MI(Y;M)=0.297
# - Layer 6 upper: MI(X;M)=6.366, MI(Y;M)=0.279
# - Layer 7 upper: MI(X;M)=2.158, MI(Y;M)=0.227
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000011
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.846, MI(Y;M)=0.969
# - Layer 3 upper: MI(X;M)=9.688, MI(Y;M)=0.540
# - Layer 4 upper: MI(X;M)=7.812, MI(Y;M)=0.367
# - Layer 5 upper: MI(X;M)=6.837, MI(Y;M)=0.330
# - Layer 6 upper: MI(X;M)=6.537, MI(Y;M)=0.316
# - Layer 7 upper: MI(X;M)=2.346, MI(Y;M)=0.260
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000012
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.838, MI(Y;M)=0.973
# - Layer 3 upper: MI(X;M)=9.688, MI(Y;M)=0.561
# - Layer 4 upper: MI(X;M)=7.867, MI(Y;M)=0.401
# - Layer 5 upper: MI(X;M)=6.915, MI(Y;M)=0.365
# - Layer 6 upper: MI(X;M)=6.657, MI(Y;M)=0.355
# - Layer 7 upper: MI(X;M)=2.523, MI(Y;M)=0.297
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000013
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.836, MI(Y;M)=0.975
# - Layer 3 upper: MI(X;M)=9.714, MI(Y;M)=0.584
# - Layer 4 upper: MI(X;M)=7.936, MI(Y;M)=0.434
# - Layer 5 upper: MI(X;M)=7.009, MI(Y;M)=0.400
# - Layer 6 upper: MI(X;M)=6.789, MI(Y;M)=0.393
# - Layer 7 upper: MI(X;M)=2.697, MI(Y;M)=0.337
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000014
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.835, MI(Y;M)=0.976
# - Layer 3 upper: MI(X;M)=9.744, MI(Y;M)=0.608
# - Layer 4 upper: MI(X;M)=8.008, MI(Y;M)=0.468
# - Layer 5 upper: MI(X;M)=7.093, MI(Y;M)=0.437
# - Layer 6 upper: MI(X;M)=6.904, MI(Y;M)=0.431
# - Layer 7 upper: MI(X;M)=2.855, MI(Y;M)=0.381
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000015
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.826, MI(Y;M)=0.977
# - Layer 3 upper: MI(X;M)=9.750, MI(Y;M)=0.638
# - Layer 4 upper: MI(X;M)=8.073, MI(Y;M)=0.507
# - Layer 5 upper: MI(X;M)=7.144, MI(Y;M)=0.474
# - Layer 6 upper: MI(X;M)=6.970, MI(Y;M)=0.468
# - Layer 7 upper: MI(X;M)=2.993, MI(Y;M)=0.425
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000016
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.826, MI(Y;M)=0.978
# - Layer 3 upper: MI(X;M)=9.827, MI(Y;M)=0.670
# - Layer 4 upper: MI(X;M)=8.182, MI(Y;M)=0.545
# - Layer 5 upper: MI(X;M)=7.246, MI(Y;M)=0.509
# - Layer 6 upper: MI(X;M)=7.083, MI(Y;M)=0.503
# - Layer 7 upper: MI(X;M)=3.130, MI(Y;M)=0.465
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000017
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.814, MI(Y;M)=0.978
# - Layer 3 upper: MI(X;M)=9.848, MI(Y;M)=0.697
# - Layer 4 upper: MI(X;M)=8.246, MI(Y;M)=0.577
# - Layer 5 upper: MI(X;M)=7.275, MI(Y;M)=0.544
# - Layer 6 upper: MI(X;M)=7.107, MI(Y;M)=0.539
# - Layer 7 upper: MI(X;M)=3.225, MI(Y;M)=0.506
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000018
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.819, MI(Y;M)=0.978
# - Layer 3 upper: MI(X;M)=9.901, MI(Y;M)=0.721
# - Layer 4 upper: MI(X;M)=8.320, MI(Y;M)=0.604
# - Layer 5 upper: MI(X;M)=7.314, MI(Y;M)=0.573
# - Layer 6 upper: MI(X;M)=7.130, MI(Y;M)=0.570
# - Layer 7 upper: MI(X;M)=3.312, MI(Y;M)=0.535
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000019
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.809, MI(Y;M)=0.978
# - Layer 3 upper: MI(X;M)=9.877, MI(Y;M)=0.737
# - Layer 4 upper: MI(X;M)=8.333, MI(Y;M)=0.628
# - Layer 5 upper: MI(X;M)=7.296, MI(Y;M)=0.597
# - Layer 6 upper: MI(X;M)=7.097, MI(Y;M)=0.594
# - Layer 7 upper: MI(X;M)=3.354, MI(Y;M)=0.560
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000020
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.823, MI(Y;M)=0.980
# - Layer 3 upper: MI(X;M)=9.935, MI(Y;M)=0.753
# - Layer 4 upper: MI(X;M)=8.388, MI(Y;M)=0.647
# - Layer 5 upper: MI(X;M)=7.315, MI(Y;M)=0.618
# - Layer 6 upper: MI(X;M)=7.089, MI(Y;M)=0.616
# - Layer 7 upper: MI(X;M)=3.397, MI(Y;M)=0.580
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000025
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.823, MI(Y;M)=0.982
# - Layer 3 upper: MI(X;M)=9.857, MI(Y;M)=0.784
# - Layer 4 upper: MI(X;M)=8.302, MI(Y;M)=0.697
# - Layer 5 upper: MI(X;M)=7.027, MI(Y;M)=0.665
# - Layer 6 upper: MI(X;M)=6.630, MI(Y;M)=0.663
# - Layer 7 upper: MI(X;M)=3.301, MI(Y;M)=0.625
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000030
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.815, MI(Y;M)=0.982
# - Layer 3 upper: MI(X;M)=9.730, MI(Y;M)=0.794
# - Layer 4 upper: MI(X;M)=8.123, MI(Y;M)=0.710
# - Layer 5 upper: MI(X;M)=6.713, MI(Y;M)=0.679
# - Layer 6 upper: MI(X;M)=6.155, MI(Y;M)=0.677
# - Layer 7 upper: MI(X;M)=3.108, MI(Y;M)=0.638
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000035
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.821, MI(Y;M)=0.985
# - Layer 3 upper: MI(X;M)=9.673, MI(Y;M)=0.804
# - Layer 4 upper: MI(X;M)=8.004, MI(Y;M)=0.722
# - Layer 5 upper: MI(X;M)=6.511, MI(Y;M)=0.691
# - Layer 6 upper: MI(X;M)=5.835, MI(Y;M)=0.688
# - Layer 7 upper: MI(X;M)=2.954, MI(Y;M)=0.645
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000040
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.825, MI(Y;M)=0.987
# - Layer 3 upper: MI(X;M)=9.640, MI(Y;M)=0.810
# - Layer 4 upper: MI(X;M)=7.933, MI(Y;M)=0.730
# - Layer 5 upper: MI(X;M)=6.385, MI(Y;M)=0.698
# - Layer 6 upper: MI(X;M)=5.606, MI(Y;M)=0.695
# - Layer 7 upper: MI(X;M)=2.843, MI(Y;M)=0.650
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000045
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.830, MI(Y;M)=0.988
# - Layer 3 upper: MI(X;M)=9.651, MI(Y;M)=0.819
# - Layer 4 upper: MI(X;M)=7.909, MI(Y;M)=0.736
# - Layer 5 upper: MI(X;M)=6.319, MI(Y;M)=0.703
# - Layer 6 upper: MI(X;M)=5.447, MI(Y;M)=0.698
# - Layer 7 upper: MI(X;M)=2.775, MI(Y;M)=0.654
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000050
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.827, MI(Y;M)=0.988
# - Layer 3 upper: MI(X;M)=9.654, MI(Y;M)=0.823
# - Layer 4 upper: MI(X;M)=7.894, MI(Y;M)=0.743
# - Layer 5 upper: MI(X;M)=6.271, MI(Y;M)=0.712
# - Layer 6 upper: MI(X;M)=5.310, MI(Y;M)=0.708
# - Layer 7 upper: MI(X;M)=2.722, MI(Y;M)=0.661
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000055
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.836, MI(Y;M)=0.989
# - Layer 3 upper: MI(X;M)=9.710, MI(Y;M)=0.829
# - Layer 4 upper: MI(X;M)=7.930, MI(Y;M)=0.753
# - Layer 5 upper: MI(X;M)=6.279, MI(Y;M)=0.723
# - Layer 6 upper: MI(X;M)=5.241, MI(Y;M)=0.720
# - Layer 7 upper: MI(X;M)=2.703, MI(Y;M)=0.666
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000060
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.837, MI(Y;M)=0.990
# - Layer 3 upper: MI(X;M)=9.749, MI(Y;M)=0.835
# - Layer 4 upper: MI(X;M)=7.967, MI(Y;M)=0.758
# - Layer 5 upper: MI(X;M)=6.298, MI(Y;M)=0.728
# - Layer 6 upper: MI(X;M)=5.187, MI(Y;M)=0.724
# - Layer 7 upper: MI(X;M)=2.686, MI(Y;M)=0.671
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000065
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.843, MI(Y;M)=0.990
# - Layer 3 upper: MI(X;M)=9.809, MI(Y;M)=0.842
# - Layer 4 upper: MI(X;M)=8.028, MI(Y;M)=0.763
# - Layer 5 upper: MI(X;M)=6.348, MI(Y;M)=0.734
# - Layer 6 upper: MI(X;M)=5.171, MI(Y;M)=0.732
# - Layer 7 upper: MI(X;M)=2.683, MI(Y;M)=0.677
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000070
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.852, MI(Y;M)=0.991
# - Layer 3 upper: MI(X;M)=9.872, MI(Y;M)=0.846
# - Layer 4 upper: MI(X;M)=8.100, MI(Y;M)=0.770
# - Layer 5 upper: MI(X;M)=6.417, MI(Y;M)=0.740
# - Layer 6 upper: MI(X;M)=5.189, MI(Y;M)=0.736
# - Layer 7 upper: MI(X;M)=2.691, MI(Y;M)=0.686
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000075
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.867, MI(Y;M)=0.992
# - Layer 3 upper: MI(X;M)=9.961, MI(Y;M)=0.851
# - Layer 4 upper: MI(X;M)=8.197, MI(Y;M)=0.773
# - Layer 5 upper: MI(X;M)=6.515, MI(Y;M)=0.744
# - Layer 6 upper: MI(X;M)=5.245, MI(Y;M)=0.741
# - Layer 7 upper: MI(X;M)=2.715, MI(Y;M)=0.691
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000080
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.872, MI(Y;M)=0.993
# - Layer 3 upper: MI(X;M)=10.003, MI(Y;M)=0.856
# - Layer 4 upper: MI(X;M)=8.271, MI(Y;M)=0.781
# - Layer 5 upper: MI(X;M)=6.587, MI(Y;M)=0.753
# - Layer 6 upper: MI(X;M)=5.265, MI(Y;M)=0.749
# - Layer 7 upper: MI(X;M)=2.716, MI(Y;M)=0.699
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000085
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.891, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.108, MI(Y;M)=0.865
# - Layer 4 upper: MI(X;M)=8.382, MI(Y;M)=0.788
# - Layer 5 upper: MI(X;M)=6.692, MI(Y;M)=0.761
# - Layer 6 upper: MI(X;M)=5.328, MI(Y;M)=0.756
# - Layer 7 upper: MI(X;M)=2.740, MI(Y;M)=0.705
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000090
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.895, MI(Y;M)=0.995
# - Layer 3 upper: MI(X;M)=10.133, MI(Y;M)=0.870
# - Layer 4 upper: MI(X;M)=8.435, MI(Y;M)=0.794
# - Layer 5 upper: MI(X;M)=6.744, MI(Y;M)=0.767
# - Layer 6 upper: MI(X;M)=5.320, MI(Y;M)=0.762
# - Layer 7 upper: MI(X;M)=2.719, MI(Y;M)=0.712
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000095
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.905, MI(Y;M)=0.995
# - Layer 3 upper: MI(X;M)=10.197, MI(Y;M)=0.878
# - Layer 4 upper: MI(X;M)=8.513, MI(Y;M)=0.803
# - Layer 5 upper: MI(X;M)=6.814, MI(Y;M)=0.776
# - Layer 6 upper: MI(X;M)=5.340, MI(Y;M)=0.769
# - Layer 7 upper: MI(X;M)=2.711, MI(Y;M)=0.718
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000100
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.911, MI(Y;M)=0.996
# - Layer 3 upper: MI(X;M)=10.242, MI(Y;M)=0.883
# - Layer 4 upper: MI(X;M)=8.581, MI(Y;M)=0.811
# - Layer 5 upper: MI(X;M)=6.871, MI(Y;M)=0.784
# - Layer 6 upper: MI(X;M)=5.349, MI(Y;M)=0.778
# - Layer 7 upper: MI(X;M)=2.698, MI(Y;M)=0.723
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000120
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.930, MI(Y;M)=0.997
# - Layer 3 upper: MI(X;M)=10.420, MI(Y;M)=0.898
# - Layer 4 upper: MI(X;M)=8.813, MI(Y;M)=0.833
# - Layer 5 upper: MI(X;M)=7.054, MI(Y;M)=0.807
# - Layer 6 upper: MI(X;M)=5.379, MI(Y;M)=0.801
# - Layer 7 upper: MI(X;M)=2.672, MI(Y;M)=0.742
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000140
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.935, MI(Y;M)=0.997
# - Layer 3 upper: MI(X;M)=10.519, MI(Y;M)=0.910
# - Layer 4 upper: MI(X;M)=8.970, MI(Y;M)=0.847
# - Layer 5 upper: MI(X;M)=7.175, MI(Y;M)=0.820
# - Layer 6 upper: MI(X;M)=5.382, MI(Y;M)=0.816
# - Layer 7 upper: MI(X;M)=2.619, MI(Y;M)=0.759
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000160
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.944, MI(Y;M)=0.997
# - Layer 3 upper: MI(X;M)=10.641, MI(Y;M)=0.919
# - Layer 4 upper: MI(X;M)=9.126, MI(Y;M)=0.858
# - Layer 5 upper: MI(X;M)=7.287, MI(Y;M)=0.832
# - Layer 6 upper: MI(X;M)=5.420, MI(Y;M)=0.829
# - Layer 7 upper: MI(X;M)=2.607, MI(Y;M)=0.774
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000180
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.946, MI(Y;M)=0.998
# - Layer 3 upper: MI(X;M)=10.709, MI(Y;M)=0.928
# - Layer 4 upper: MI(X;M)=9.250, MI(Y;M)=0.871
# - Layer 5 upper: MI(X;M)=7.372, MI(Y;M)=0.845
# - Layer 6 upper: MI(X;M)=5.409, MI(Y;M)=0.841
# - Layer 7 upper: MI(X;M)=2.542, MI(Y;M)=0.788
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000200
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.950, MI(Y;M)=0.998
# - Layer 3 upper: MI(X;M)=10.780, MI(Y;M)=0.937
# - Layer 4 upper: MI(X;M)=9.355, MI(Y;M)=0.883
# - Layer 5 upper: MI(X;M)=7.442, MI(Y;M)=0.860
# - Layer 6 upper: MI(X;M)=5.406, MI(Y;M)=0.858
# - Layer 7 upper: MI(X;M)=2.501, MI(Y;M)=0.803
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000220
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.957, MI(Y;M)=0.998
# - Layer 3 upper: MI(X;M)=10.849, MI(Y;M)=0.944
# - Layer 4 upper: MI(X;M)=9.436, MI(Y;M)=0.894
# - Layer 5 upper: MI(X;M)=7.479, MI(Y;M)=0.870
# - Layer 6 upper: MI(X;M)=5.356, MI(Y;M)=0.866
# - Layer 7 upper: MI(X;M)=2.451, MI(Y;M)=0.816
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000240
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.963, MI(Y;M)=0.998
# - Layer 3 upper: MI(X;M)=10.910, MI(Y;M)=0.950
# - Layer 4 upper: MI(X;M)=9.487, MI(Y;M)=0.904
# - Layer 5 upper: MI(X;M)=7.478, MI(Y;M)=0.884
# - Layer 6 upper: MI(X;M)=5.263, MI(Y;M)=0.881
# - Layer 7 upper: MI(X;M)=2.383, MI(Y;M)=0.831
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000260
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.968, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=10.955, MI(Y;M)=0.956
# - Layer 4 upper: MI(X;M)=9.525, MI(Y;M)=0.916
# - Layer 5 upper: MI(X;M)=7.452, MI(Y;M)=0.895
# - Layer 6 upper: MI(X;M)=5.152, MI(Y;M)=0.892
# - Layer 7 upper: MI(X;M)=2.308, MI(Y;M)=0.843
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000280
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.971, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=10.975, MI(Y;M)=0.962
# - Layer 4 upper: MI(X;M)=9.534, MI(Y;M)=0.924
# - Layer 5 upper: MI(X;M)=7.406, MI(Y;M)=0.902
# - Layer 6 upper: MI(X;M)=5.039, MI(Y;M)=0.899
# - Layer 7 upper: MI(X;M)=2.243, MI(Y;M)=0.853
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000300
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.974, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.020, MI(Y;M)=0.965
# - Layer 4 upper: MI(X;M)=9.576, MI(Y;M)=0.927
# - Layer 5 upper: MI(X;M)=7.409, MI(Y;M)=0.906
# - Layer 6 upper: MI(X;M)=4.986, MI(Y;M)=0.903
# - Layer 7 upper: MI(X;M)=2.192, MI(Y;M)=0.860
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000320
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.975, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.034, MI(Y;M)=0.966
# - Layer 4 upper: MI(X;M)=9.598, MI(Y;M)=0.931
# - Layer 5 upper: MI(X;M)=7.399, MI(Y;M)=0.911
# - Layer 6 upper: MI(X;M)=4.920, MI(Y;M)=0.905
# - Layer 7 upper: MI(X;M)=2.142, MI(Y;M)=0.864
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000340
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.978, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.096, MI(Y;M)=0.969
# - Layer 4 upper: MI(X;M)=9.665, MI(Y;M)=0.938
# - Layer 5 upper: MI(X;M)=7.429, MI(Y;M)=0.918
# - Layer 6 upper: MI(X;M)=4.917, MI(Y;M)=0.915
# - Layer 7 upper: MI(X;M)=2.119, MI(Y;M)=0.872
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000360
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.979, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.113, MI(Y;M)=0.971
# - Layer 4 upper: MI(X;M)=9.698, MI(Y;M)=0.942
# - Layer 5 upper: MI(X;M)=7.447, MI(Y;M)=0.923
# - Layer 6 upper: MI(X;M)=4.899, MI(Y;M)=0.919
# - Layer 7 upper: MI(X;M)=2.086, MI(Y;M)=0.875
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000380
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.979, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.123, MI(Y;M)=0.973
# - Layer 4 upper: MI(X;M)=9.729, MI(Y;M)=0.945
# - Layer 5 upper: MI(X;M)=7.465, MI(Y;M)=0.926
# - Layer 6 upper: MI(X;M)=4.877, MI(Y;M)=0.922
# - Layer 7 upper: MI(X;M)=2.052, MI(Y;M)=0.877
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000400
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.980, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.140, MI(Y;M)=0.974
# - Layer 4 upper: MI(X;M)=9.761, MI(Y;M)=0.948
# - Layer 5 upper: MI(X;M)=7.493, MI(Y;M)=0.927
# - Layer 6 upper: MI(X;M)=4.882, MI(Y;M)=0.923
# - Layer 7 upper: MI(X;M)=2.034, MI(Y;M)=0.879
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000420
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.981, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.158, MI(Y;M)=0.975
# - Layer 4 upper: MI(X;M)=9.801, MI(Y;M)=0.949
# - Layer 5 upper: MI(X;M)=7.523, MI(Y;M)=0.930
# - Layer 6 upper: MI(X;M)=4.872, MI(Y;M)=0.927
# - Layer 7 upper: MI(X;M)=2.002, MI(Y;M)=0.882
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000440
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.981, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.178, MI(Y;M)=0.976
# - Layer 4 upper: MI(X;M)=9.844, MI(Y;M)=0.951
# - Layer 5 upper: MI(X;M)=7.563, MI(Y;M)=0.933
# - Layer 6 upper: MI(X;M)=4.897, MI(Y;M)=0.928
# - Layer 7 upper: MI(X;M)=1.994, MI(Y;M)=0.885
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000460
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.981, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.186, MI(Y;M)=0.977
# - Layer 4 upper: MI(X;M)=9.877, MI(Y;M)=0.951
# - Layer 5 upper: MI(X;M)=7.589, MI(Y;M)=0.935
# - Layer 6 upper: MI(X;M)=4.888, MI(Y;M)=0.933
# - Layer 7 upper: MI(X;M)=1.965, MI(Y;M)=0.889
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000480
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.982, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.203, MI(Y;M)=0.977
# - Layer 4 upper: MI(X;M)=9.920, MI(Y;M)=0.952
# - Layer 5 upper: MI(X;M)=7.630, MI(Y;M)=0.938
# - Layer 6 upper: MI(X;M)=4.904, MI(Y;M)=0.936
# - Layer 7 upper: MI(X;M)=1.951, MI(Y;M)=0.891
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000500
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.983, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.228, MI(Y;M)=0.978
# - Layer 4 upper: MI(X;M)=9.968, MI(Y;M)=0.954
# - Layer 5 upper: MI(X;M)=7.669, MI(Y;M)=0.939
# - Layer 6 upper: MI(X;M)=4.913, MI(Y;M)=0.939
# - Layer 7 upper: MI(X;M)=1.948, MI(Y;M)=0.892
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000520
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.982, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.211, MI(Y;M)=0.978
# - Layer 4 upper: MI(X;M)=9.968, MI(Y;M)=0.955
# - Layer 5 upper: MI(X;M)=7.694, MI(Y;M)=0.939
# - Layer 6 upper: MI(X;M)=4.940, MI(Y;M)=0.938
# - Layer 7 upper: MI(X;M)=1.919, MI(Y;M)=0.891
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000540
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.983, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.228, MI(Y;M)=0.979
# - Layer 4 upper: MI(X;M)=10.009, MI(Y;M)=0.957
# - Layer 5 upper: MI(X;M)=7.733, MI(Y;M)=0.943
# - Layer 6 upper: MI(X;M)=4.943, MI(Y;M)=0.942
# - Layer 7 upper: MI(X;M)=1.914, MI(Y;M)=0.896
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000560
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.982, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.213, MI(Y;M)=0.978
# - Layer 4 upper: MI(X;M)=10.014, MI(Y;M)=0.957
# - Layer 5 upper: MI(X;M)=7.755, MI(Y;M)=0.942
# - Layer 6 upper: MI(X;M)=4.946, MI(Y;M)=0.940
# - Layer 7 upper: MI(X;M)=1.880, MI(Y;M)=0.894
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000580
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.982, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.230, MI(Y;M)=0.979
# - Layer 4 upper: MI(X;M)=10.051, MI(Y;M)=0.958
# - Layer 5 upper: MI(X;M)=7.803, MI(Y;M)=0.946
# - Layer 6 upper: MI(X;M)=4.982, MI(Y;M)=0.945
# - Layer 7 upper: MI(X;M)=1.887, MI(Y;M)=0.897
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000600
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.982, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.227, MI(Y;M)=0.979
# - Layer 4 upper: MI(X;M)=10.061, MI(Y;M)=0.959
# - Layer 5 upper: MI(X;M)=7.825, MI(Y;M)=0.948
# - Layer 6 upper: MI(X;M)=4.990, MI(Y;M)=0.948
# - Layer 7 upper: MI(X;M)=1.869, MI(Y;M)=0.898
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000620
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.982, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.217, MI(Y;M)=0.979
# - Layer 4 upper: MI(X;M)=10.054, MI(Y;M)=0.959
# - Layer 5 upper: MI(X;M)=7.816, MI(Y;M)=0.947
# - Layer 6 upper: MI(X;M)=4.949, MI(Y;M)=0.944
# - Layer 7 upper: MI(X;M)=1.832, MI(Y;M)=0.896
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000640
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.982, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.234, MI(Y;M)=0.980
# - Layer 4 upper: MI(X;M)=10.081, MI(Y;M)=0.961
# - Layer 5 upper: MI(X;M)=7.843, MI(Y;M)=0.949
# - Layer 6 upper: MI(X;M)=4.961, MI(Y;M)=0.946
# - Layer 7 upper: MI(X;M)=1.836, MI(Y;M)=0.899
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000660
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.982, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.247, MI(Y;M)=0.979
# - Layer 4 upper: MI(X;M)=10.114, MI(Y;M)=0.961
# - Layer 5 upper: MI(X;M)=7.874, MI(Y;M)=0.951
# - Layer 6 upper: MI(X;M)=4.975, MI(Y;M)=0.951
# - Layer 7 upper: MI(X;M)=1.846, MI(Y;M)=0.901
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000680
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.982, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.248, MI(Y;M)=0.979
# - Layer 4 upper: MI(X;M)=10.118, MI(Y;M)=0.962
# - Layer 5 upper: MI(X;M)=7.884, MI(Y;M)=0.950
# - Layer 6 upper: MI(X;M)=4.980, MI(Y;M)=0.949
# - Layer 7 upper: MI(X;M)=1.839, MI(Y;M)=0.901
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000700
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.982, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.246, MI(Y;M)=0.980
# - Layer 4 upper: MI(X;M)=10.122, MI(Y;M)=0.962
# - Layer 5 upper: MI(X;M)=7.886, MI(Y;M)=0.950
# - Layer 6 upper: MI(X;M)=4.974, MI(Y;M)=0.949
# - Layer 7 upper: MI(X;M)=1.819, MI(Y;M)=0.903
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000720
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.981, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.241, MI(Y;M)=0.980
# - Layer 4 upper: MI(X;M)=10.123, MI(Y;M)=0.963
# - Layer 5 upper: MI(X;M)=7.883, MI(Y;M)=0.950
# - Layer 6 upper: MI(X;M)=4.958, MI(Y;M)=0.949
# - Layer 7 upper: MI(X;M)=1.802, MI(Y;M)=0.903
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000740
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.980, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.242, MI(Y;M)=0.980
# - Layer 4 upper: MI(X;M)=10.130, MI(Y;M)=0.963
# - Layer 5 upper: MI(X;M)=7.882, MI(Y;M)=0.951
# - Layer 6 upper: MI(X;M)=4.933, MI(Y;M)=0.950
# - Layer 7 upper: MI(X;M)=1.787, MI(Y;M)=0.904
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000760
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.981, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.268, MI(Y;M)=0.981
# - Layer 4 upper: MI(X;M)=10.167, MI(Y;M)=0.963
# - Layer 5 upper: MI(X;M)=7.904, MI(Y;M)=0.953
# - Layer 6 upper: MI(X;M)=4.936, MI(Y;M)=0.953
# - Layer 7 upper: MI(X;M)=1.814, MI(Y;M)=0.907
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000780
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.980, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.265, MI(Y;M)=0.982
# - Layer 4 upper: MI(X;M)=10.172, MI(Y;M)=0.963
# - Layer 5 upper: MI(X;M)=7.913, MI(Y;M)=0.954
# - Layer 6 upper: MI(X;M)=4.937, MI(Y;M)=0.955
# - Layer 7 upper: MI(X;M)=1.795, MI(Y;M)=0.910
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000800
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.979, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.266, MI(Y;M)=0.982
# - Layer 4 upper: MI(X;M)=10.171, MI(Y;M)=0.963
# - Layer 5 upper: MI(X;M)=7.924, MI(Y;M)=0.954
# - Layer 6 upper: MI(X;M)=4.962, MI(Y;M)=0.955
# - Layer 7 upper: MI(X;M)=1.794, MI(Y;M)=0.908
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000820
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.978, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.270, MI(Y;M)=0.982
# - Layer 4 upper: MI(X;M)=10.178, MI(Y;M)=0.964
# - Layer 5 upper: MI(X;M)=7.910, MI(Y;M)=0.955
# - Layer 6 upper: MI(X;M)=4.910, MI(Y;M)=0.953
# - Layer 7 upper: MI(X;M)=1.787, MI(Y;M)=0.911
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000840
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.977, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.267, MI(Y;M)=0.983
# - Layer 4 upper: MI(X;M)=10.173, MI(Y;M)=0.964
# - Layer 5 upper: MI(X;M)=7.884, MI(Y;M)=0.956
# - Layer 6 upper: MI(X;M)=4.867, MI(Y;M)=0.954
# - Layer 7 upper: MI(X;M)=1.755, MI(Y;M)=0.911
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000860
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.977, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.280, MI(Y;M)=0.982
# - Layer 4 upper: MI(X;M)=10.190, MI(Y;M)=0.964
# - Layer 5 upper: MI(X;M)=7.885, MI(Y;M)=0.957
# - Layer 6 upper: MI(X;M)=4.844, MI(Y;M)=0.957
# - Layer 7 upper: MI(X;M)=1.766, MI(Y;M)=0.912
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000880
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.976, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.264, MI(Y;M)=0.983
# - Layer 4 upper: MI(X;M)=10.169, MI(Y;M)=0.965
# - Layer 5 upper: MI(X;M)=7.859, MI(Y;M)=0.956
# - Layer 6 upper: MI(X;M)=4.821, MI(Y;M)=0.954
# - Layer 7 upper: MI(X;M)=1.719, MI(Y;M)=0.909
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000900
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.975, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.259, MI(Y;M)=0.983
# - Layer 4 upper: MI(X;M)=10.162, MI(Y;M)=0.965
# - Layer 5 upper: MI(X;M)=7.847, MI(Y;M)=0.956
# - Layer 6 upper: MI(X;M)=4.795, MI(Y;M)=0.953
# - Layer 7 upper: MI(X;M)=1.694, MI(Y;M)=0.906
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000920
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.976, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.289, MI(Y;M)=0.984
# - Layer 4 upper: MI(X;M)=10.202, MI(Y;M)=0.967
# - Layer 5 upper: MI(X;M)=7.873, MI(Y;M)=0.959
# - Layer 6 upper: MI(X;M)=4.811, MI(Y;M)=0.957
# - Layer 7 upper: MI(X;M)=1.742, MI(Y;M)=0.915
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000940
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.976, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.283, MI(Y;M)=0.983
# - Layer 4 upper: MI(X;M)=10.192, MI(Y;M)=0.966
# - Layer 5 upper: MI(X;M)=7.852, MI(Y;M)=0.958
# - Layer 6 upper: MI(X;M)=4.776, MI(Y;M)=0.958
# - Layer 7 upper: MI(X;M)=1.720, MI(Y;M)=0.916
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000960
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.976, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.289, MI(Y;M)=0.984
# - Layer 4 upper: MI(X;M)=10.205, MI(Y;M)=0.967
# - Layer 5 upper: MI(X;M)=7.851, MI(Y;M)=0.960
# - Layer 6 upper: MI(X;M)=4.754, MI(Y;M)=0.961
# - Layer 7 upper: MI(X;M)=1.717, MI(Y;M)=0.917
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00000980
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.976, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.299, MI(Y;M)=0.984
# - Layer 4 upper: MI(X;M)=10.212, MI(Y;M)=0.967
# - Layer 5 upper: MI(X;M)=7.845, MI(Y;M)=0.961
# - Layer 6 upper: MI(X;M)=4.734, MI(Y;M)=0.961
# - Layer 7 upper: MI(X;M)=1.732, MI(Y;M)=0.916
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001000
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.975, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.281, MI(Y;M)=0.983
# - Layer 4 upper: MI(X;M)=10.183, MI(Y;M)=0.968
# - Layer 5 upper: MI(X;M)=7.805, MI(Y;M)=0.962
# - Layer 6 upper: MI(X;M)=4.688, MI(Y;M)=0.960
# - Layer 7 upper: MI(X;M)=1.676, MI(Y;M)=0.916
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001020
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.975, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.279, MI(Y;M)=0.984
# - Layer 4 upper: MI(X;M)=10.183, MI(Y;M)=0.968
# - Layer 5 upper: MI(X;M)=7.799, MI(Y;M)=0.961
# - Layer 6 upper: MI(X;M)=4.676, MI(Y;M)=0.960
# - Layer 7 upper: MI(X;M)=1.662, MI(Y;M)=0.914
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001040
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.975, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.289, MI(Y;M)=0.984
# - Layer 4 upper: MI(X;M)=10.193, MI(Y;M)=0.969
# - Layer 5 upper: MI(X;M)=7.783, MI(Y;M)=0.962
# - Layer 6 upper: MI(X;M)=4.630, MI(Y;M)=0.962
# - Layer 7 upper: MI(X;M)=1.669, MI(Y;M)=0.918
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001060
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.975, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.287, MI(Y;M)=0.984
# - Layer 4 upper: MI(X;M)=10.184, MI(Y;M)=0.970
# - Layer 5 upper: MI(X;M)=7.763, MI(Y;M)=0.961
# - Layer 6 upper: MI(X;M)=4.606, MI(Y;M)=0.960
# - Layer 7 upper: MI(X;M)=1.658, MI(Y;M)=0.918
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001080
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.975, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.293, MI(Y;M)=0.984
# - Layer 4 upper: MI(X;M)=10.189, MI(Y;M)=0.970
# - Layer 5 upper: MI(X;M)=7.761, MI(Y;M)=0.962
# - Layer 6 upper: MI(X;M)=4.591, MI(Y;M)=0.960
# - Layer 7 upper: MI(X;M)=1.666, MI(Y;M)=0.919
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001100
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.975, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.287, MI(Y;M)=0.984
# - Layer 4 upper: MI(X;M)=10.172, MI(Y;M)=0.971
# - Layer 5 upper: MI(X;M)=7.727, MI(Y;M)=0.962
# - Layer 6 upper: MI(X;M)=4.541, MI(Y;M)=0.960
# - Layer 7 upper: MI(X;M)=1.638, MI(Y;M)=0.918
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001120
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.976, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.292, MI(Y;M)=0.984
# - Layer 4 upper: MI(X;M)=10.171, MI(Y;M)=0.971
# - Layer 5 upper: MI(X;M)=7.708, MI(Y;M)=0.962
# - Layer 6 upper: MI(X;M)=4.511, MI(Y;M)=0.961
# - Layer 7 upper: MI(X;M)=1.644, MI(Y;M)=0.921
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001140
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.975, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.287, MI(Y;M)=0.984
# - Layer 4 upper: MI(X;M)=10.157, MI(Y;M)=0.972
# - Layer 5 upper: MI(X;M)=7.705, MI(Y;M)=0.963
# - Layer 6 upper: MI(X;M)=4.512, MI(Y;M)=0.960
# - Layer 7 upper: MI(X;M)=1.620, MI(Y;M)=0.920
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001160
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.975, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.281, MI(Y;M)=0.985
# - Layer 4 upper: MI(X;M)=10.140, MI(Y;M)=0.972
# - Layer 5 upper: MI(X;M)=7.679, MI(Y;M)=0.962
# - Layer 6 upper: MI(X;M)=4.489, MI(Y;M)=0.960
# - Layer 7 upper: MI(X;M)=1.601, MI(Y;M)=0.921
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001180
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.975, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.292, MI(Y;M)=0.984
# - Layer 4 upper: MI(X;M)=10.140, MI(Y;M)=0.972
# - Layer 5 upper: MI(X;M)=7.648, MI(Y;M)=0.965
# - Layer 6 upper: MI(X;M)=4.424, MI(Y;M)=0.964
# - Layer 7 upper: MI(X;M)=1.611, MI(Y;M)=0.922
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001200
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.975, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.294, MI(Y;M)=0.985
# - Layer 4 upper: MI(X;M)=10.123, MI(Y;M)=0.973
# - Layer 5 upper: MI(X;M)=7.597, MI(Y;M)=0.966
# - Layer 6 upper: MI(X;M)=4.354, MI(Y;M)=0.965
# - Layer 7 upper: MI(X;M)=1.600, MI(Y;M)=0.923
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001220
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.976, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.297, MI(Y;M)=0.985
# - Layer 4 upper: MI(X;M)=10.110, MI(Y;M)=0.973
# - Layer 5 upper: MI(X;M)=7.560, MI(Y;M)=0.965
# - Layer 6 upper: MI(X;M)=4.295, MI(Y;M)=0.964
# - Layer 7 upper: MI(X;M)=1.578, MI(Y;M)=0.922
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001240
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.976, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.303, MI(Y;M)=0.985
# - Layer 4 upper: MI(X;M)=10.101, MI(Y;M)=0.973
# - Layer 5 upper: MI(X;M)=7.546, MI(Y;M)=0.965
# - Layer 6 upper: MI(X;M)=4.277, MI(Y;M)=0.963
# - Layer 7 upper: MI(X;M)=1.573, MI(Y;M)=0.924
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001260
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.976, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.321, MI(Y;M)=0.986
# - Layer 4 upper: MI(X;M)=10.110, MI(Y;M)=0.974
# - Layer 5 upper: MI(X;M)=7.521, MI(Y;M)=0.968
# - Layer 6 upper: MI(X;M)=4.216, MI(Y;M)=0.966
# - Layer 7 upper: MI(X;M)=1.601, MI(Y;M)=0.925
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001280
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.976, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.305, MI(Y;M)=0.986
# - Layer 4 upper: MI(X;M)=10.076, MI(Y;M)=0.975
# - Layer 5 upper: MI(X;M)=7.482, MI(Y;M)=0.967
# - Layer 6 upper: MI(X;M)=4.164, MI(Y;M)=0.963
# - Layer 7 upper: MI(X;M)=1.538, MI(Y;M)=0.924
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001300
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.976, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.315, MI(Y;M)=0.987
# - Layer 4 upper: MI(X;M)=10.064, MI(Y;M)=0.976
# - Layer 5 upper: MI(X;M)=7.426, MI(Y;M)=0.968
# - Layer 6 upper: MI(X;M)=4.081, MI(Y;M)=0.965
# - Layer 7 upper: MI(X;M)=1.538, MI(Y;M)=0.926
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001320
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.976, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.310, MI(Y;M)=0.987
# - Layer 4 upper: MI(X;M)=10.036, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=7.385, MI(Y;M)=0.969
# - Layer 6 upper: MI(X;M)=4.028, MI(Y;M)=0.964
# - Layer 7 upper: MI(X;M)=1.490, MI(Y;M)=0.924
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001340
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.977, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.319, MI(Y;M)=0.987
# - Layer 4 upper: MI(X;M)=10.034, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=7.366, MI(Y;M)=0.971
# - Layer 6 upper: MI(X;M)=3.989, MI(Y;M)=0.967
# - Layer 7 upper: MI(X;M)=1.491, MI(Y;M)=0.926
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001360
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.978, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.332, MI(Y;M)=0.988
# - Layer 4 upper: MI(X;M)=10.029, MI(Y;M)=0.979
# - Layer 5 upper: MI(X;M)=7.337, MI(Y;M)=0.971
# - Layer 6 upper: MI(X;M)=3.940, MI(Y;M)=0.967
# - Layer 7 upper: MI(X;M)=1.497, MI(Y;M)=0.928
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001380
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.978, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.332, MI(Y;M)=0.988
# - Layer 4 upper: MI(X;M)=10.019, MI(Y;M)=0.980
# - Layer 5 upper: MI(X;M)=7.318, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=3.902, MI(Y;M)=0.968
# - Layer 7 upper: MI(X;M)=1.483, MI(Y;M)=0.926
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001400
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.978, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.332, MI(Y;M)=0.988
# - Layer 4 upper: MI(X;M)=9.999, MI(Y;M)=0.979
# - Layer 5 upper: MI(X;M)=7.294, MI(Y;M)=0.970
# - Layer 6 upper: MI(X;M)=3.878, MI(Y;M)=0.964
# - Layer 7 upper: MI(X;M)=1.451, MI(Y;M)=0.925
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001420
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.979, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.338, MI(Y;M)=0.989
# - Layer 4 upper: MI(X;M)=9.988, MI(Y;M)=0.982
# - Layer 5 upper: MI(X;M)=7.262, MI(Y;M)=0.975
# - Layer 6 upper: MI(X;M)=3.826, MI(Y;M)=0.969
# - Layer 7 upper: MI(X;M)=1.446, MI(Y;M)=0.926
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001440
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.980, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.357, MI(Y;M)=0.989
# - Layer 4 upper: MI(X;M)=9.999, MI(Y;M)=0.982
# - Layer 5 upper: MI(X;M)=7.271, MI(Y;M)=0.976
# - Layer 6 upper: MI(X;M)=3.834, MI(Y;M)=0.972
# - Layer 7 upper: MI(X;M)=1.487, MI(Y;M)=0.932
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001460
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.980, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.349, MI(Y;M)=0.989
# - Layer 4 upper: MI(X;M)=9.969, MI(Y;M)=0.983
# - Layer 5 upper: MI(X;M)=7.229, MI(Y;M)=0.976
# - Layer 6 upper: MI(X;M)=3.766, MI(Y;M)=0.970
# - Layer 7 upper: MI(X;M)=1.437, MI(Y;M)=0.929
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001480
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.980, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.347, MI(Y;M)=0.990
# - Layer 4 upper: MI(X;M)=9.944, MI(Y;M)=0.983
# - Layer 5 upper: MI(X;M)=7.179, MI(Y;M)=0.977
# - Layer 6 upper: MI(X;M)=3.705, MI(Y;M)=0.971
# - Layer 7 upper: MI(X;M)=1.420, MI(Y;M)=0.929
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001500
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.980, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.344, MI(Y;M)=0.990
# - Layer 4 upper: MI(X;M)=9.918, MI(Y;M)=0.984
# - Layer 5 upper: MI(X;M)=7.144, MI(Y;M)=0.976
# - Layer 6 upper: MI(X;M)=3.663, MI(Y;M)=0.969
# - Layer 7 upper: MI(X;M)=1.404, MI(Y;M)=0.929
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001520
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.981, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.346, MI(Y;M)=0.990
# - Layer 4 upper: MI(X;M)=9.897, MI(Y;M)=0.984
# - Layer 5 upper: MI(X;M)=7.121, MI(Y;M)=0.975
# - Layer 6 upper: MI(X;M)=3.636, MI(Y;M)=0.968
# - Layer 7 upper: MI(X;M)=1.388, MI(Y;M)=0.928
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001540
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.981, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.358, MI(Y;M)=0.990
# - Layer 4 upper: MI(X;M)=9.894, MI(Y;M)=0.983
# - Layer 5 upper: MI(X;M)=7.102, MI(Y;M)=0.977
# - Layer 6 upper: MI(X;M)=3.599, MI(Y;M)=0.971
# - Layer 7 upper: MI(X;M)=1.398, MI(Y;M)=0.932
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001560
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.981, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.349, MI(Y;M)=0.990
# - Layer 4 upper: MI(X;M)=9.859, MI(Y;M)=0.984
# - Layer 5 upper: MI(X;M)=7.067, MI(Y;M)=0.977
# - Layer 6 upper: MI(X;M)=3.556, MI(Y;M)=0.969
# - Layer 7 upper: MI(X;M)=1.373, MI(Y;M)=0.930
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001580
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.982, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.362, MI(Y;M)=0.990
# - Layer 4 upper: MI(X;M)=9.858, MI(Y;M)=0.984
# - Layer 5 upper: MI(X;M)=7.053, MI(Y;M)=0.977
# - Layer 6 upper: MI(X;M)=3.531, MI(Y;M)=0.971
# - Layer 7 upper: MI(X;M)=1.379, MI(Y;M)=0.933
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001600
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.982, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.354, MI(Y;M)=0.990
# - Layer 4 upper: MI(X;M)=9.835, MI(Y;M)=0.984
# - Layer 5 upper: MI(X;M)=7.056, MI(Y;M)=0.975
# - Layer 6 upper: MI(X;M)=3.569, MI(Y;M)=0.969
# - Layer 7 upper: MI(X;M)=1.376, MI(Y;M)=0.933
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001620
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.982, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.353, MI(Y;M)=0.990
# - Layer 4 upper: MI(X;M)=9.813, MI(Y;M)=0.984
# - Layer 5 upper: MI(X;M)=7.004, MI(Y;M)=0.976
# - Layer 6 upper: MI(X;M)=3.499, MI(Y;M)=0.969
# - Layer 7 upper: MI(X;M)=1.362, MI(Y;M)=0.933
# Doing rawdata/tanh_12-10-7-5-4-3-2/epoch00001640
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.982, MI(Y;M)=0.999
# - Layer 3 upper: MI(X;M)=11.363, MI(Y;M)=0.990
# - Layer 4 upper: MI(X;M)=9.813, MI(Y;M)=0.985
# - Layer 5 upper: MI(X;M)=6.972, MI(Y;M)=0.978
# ...
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00004200
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.885, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.479, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.321, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.326, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.951, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=6.154, MI(Y;M)=0.967
# - Layer 7 upper: MI(X;M)=1.012, MI(Y;M)=0.945
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00004300
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.885, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.480, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.306, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.298, MI(Y;M)=0.976
# - Layer 5 upper: MI(X;M)=6.896, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=6.174, MI(Y;M)=0.968
# - Layer 7 upper: MI(X;M)=1.021, MI(Y;M)=0.946
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00004400
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.886, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.482, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.310, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.303, MI(Y;M)=0.976
# - Layer 5 upper: MI(X;M)=6.905, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=6.165, MI(Y;M)=0.969
# - Layer 7 upper: MI(X;M)=1.021, MI(Y;M)=0.946
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00004500
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.886, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.483, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.313, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.307, MI(Y;M)=0.976
# - Layer 5 upper: MI(X;M)=6.918, MI(Y;M)=0.974
# - Layer 6 upper: MI(X;M)=6.165, MI(Y;M)=0.970
# - Layer 7 upper: MI(X;M)=1.019, MI(Y;M)=0.947
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00004600
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.886, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.483, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.316, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.316, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.931, MI(Y;M)=0.974
# - Layer 6 upper: MI(X;M)=6.166, MI(Y;M)=0.970
# - Layer 7 upper: MI(X;M)=1.019, MI(Y;M)=0.946
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00004700
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.885, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.482, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.317, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.322, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.934, MI(Y;M)=0.975
# - Layer 6 upper: MI(X;M)=6.175, MI(Y;M)=0.970
# - Layer 7 upper: MI(X;M)=1.017, MI(Y;M)=0.945
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00004800
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.885, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.482, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.319, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.333, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.939, MI(Y;M)=0.975
# - Layer 6 upper: MI(X;M)=6.156, MI(Y;M)=0.970
# - Layer 7 upper: MI(X;M)=1.017, MI(Y;M)=0.945
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00004900
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.886, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.485, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.317, MI(Y;M)=0.991
# - Layer 4 upper: MI(X;M)=8.324, MI(Y;M)=0.973
# - Layer 5 upper: MI(X;M)=6.937, MI(Y;M)=0.969
# - Layer 6 upper: MI(X;M)=6.206, MI(Y;M)=0.961
# - Layer 7 upper: MI(X;M)=1.058, MI(Y;M)=0.932
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00005000
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.475, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.305, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.327, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.916, MI(Y;M)=0.972
# - Layer 6 upper: MI(X;M)=6.159, MI(Y;M)=0.968
# - Layer 7 upper: MI(X;M)=1.019, MI(Y;M)=0.947
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00005100
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.881, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.478, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.312, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.338, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.921, MI(Y;M)=0.974
# - Layer 6 upper: MI(X;M)=6.156, MI(Y;M)=0.969
# - Layer 7 upper: MI(X;M)=1.021, MI(Y;M)=0.947
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00005200
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.882, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.480, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.317, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.346, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=6.933, MI(Y;M)=0.975
# - Layer 6 upper: MI(X;M)=6.152, MI(Y;M)=0.969
# - Layer 7 upper: MI(X;M)=1.021, MI(Y;M)=0.946
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00005300
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.883, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.482, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.320, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.352, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=6.942, MI(Y;M)=0.975
# - Layer 6 upper: MI(X;M)=6.163, MI(Y;M)=0.973
# - Layer 7 upper: MI(X;M)=1.020, MI(Y;M)=0.946
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00005400
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.883, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.482, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.322, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.359, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=6.946, MI(Y;M)=0.975
# - Layer 6 upper: MI(X;M)=6.159, MI(Y;M)=0.970
# - Layer 7 upper: MI(X;M)=1.020, MI(Y;M)=0.947
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00005500
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.883, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.482, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.323, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.364, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=6.944, MI(Y;M)=0.974
# - Layer 6 upper: MI(X;M)=6.150, MI(Y;M)=0.970
# - Layer 7 upper: MI(X;M)=1.019, MI(Y;M)=0.947
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00005600
# - Layer 0 upper: MI(X;M)=11.994, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.883, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.482, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.325, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.371, MI(Y;M)=0.979
# - Layer 5 upper: MI(X;M)=6.954, MI(Y;M)=0.974
# - Layer 6 upper: MI(X;M)=6.160, MI(Y;M)=0.970
# - Layer 7 upper: MI(X;M)=1.017, MI(Y;M)=0.946
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00005700
# - Layer 0 upper: MI(X;M)=11.993, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.868, MI(Y;M)=0.998
# - Layer 2 upper: MI(X;M)=11.465, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.317, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.404, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=6.975, MI(Y;M)=0.974
# - Layer 6 upper: MI(X;M)=6.309, MI(Y;M)=0.972
# - Layer 7 upper: MI(X;M)=1.074, MI(Y;M)=0.940
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00005800
# - Layer 0 upper: MI(X;M)=11.993, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.876, MI(Y;M)=0.998
# - Layer 2 upper: MI(X;M)=11.472, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.301, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.358, MI(Y;M)=0.976
# - Layer 5 upper: MI(X;M)=6.919, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=6.177, MI(Y;M)=0.968
# - Layer 7 upper: MI(X;M)=1.016, MI(Y;M)=0.947
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00005900
# - Layer 0 upper: MI(X;M)=11.993, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.878, MI(Y;M)=0.998
# - Layer 2 upper: MI(X;M)=11.476, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.306, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.361, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.925, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=6.173, MI(Y;M)=0.971
# - Layer 7 upper: MI(X;M)=1.016, MI(Y;M)=0.947
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00006000
# - Layer 0 upper: MI(X;M)=11.993, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.879, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.478, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.311, MI(Y;M)=0.993
# - Layer 4 upper: MI(X;M)=8.366, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.933, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=6.158, MI(Y;M)=0.969
# - Layer 7 upper: MI(X;M)=1.016, MI(Y;M)=0.947
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00006100
# - Layer 0 upper: MI(X;M)=11.993, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.480, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.315, MI(Y;M)=0.993
# - Layer 4 upper: MI(X;M)=8.372, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=6.939, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=6.157, MI(Y;M)=0.970
# - Layer 7 upper: MI(X;M)=1.017, MI(Y;M)=0.947
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00006200
# - Layer 0 upper: MI(X;M)=11.993, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.481, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.320, MI(Y;M)=0.993
# - Layer 4 upper: MI(X;M)=8.381, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=6.944, MI(Y;M)=0.974
# - Layer 6 upper: MI(X;M)=6.154, MI(Y;M)=0.970
# - Layer 7 upper: MI(X;M)=1.017, MI(Y;M)=0.946
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00006300
# - Layer 0 upper: MI(X;M)=11.993, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.881, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.481, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.322, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.386, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=6.949, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=6.152, MI(Y;M)=0.969
# - Layer 7 upper: MI(X;M)=1.015, MI(Y;M)=0.946
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00006400
# - Layer 0 upper: MI(X;M)=11.993, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.881, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.482, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.325, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.392, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=6.959, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=6.157, MI(Y;M)=0.968
# - Layer 7 upper: MI(X;M)=1.015, MI(Y;M)=0.946
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00006500
# - Layer 0 upper: MI(X;M)=11.992, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.881, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.481, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.320, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.391, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.961, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=6.160, MI(Y;M)=0.969
# - Layer 7 upper: MI(X;M)=1.023, MI(Y;M)=0.947
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00006600
# - Layer 0 upper: MI(X;M)=11.992, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.472, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.312, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.382, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.948, MI(Y;M)=0.976
# - Layer 6 upper: MI(X;M)=6.163, MI(Y;M)=0.973
# - Layer 7 upper: MI(X;M)=1.025, MI(Y;M)=0.949
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00006700
# - Layer 0 upper: MI(X;M)=11.992, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.474, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.315, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.388, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=6.947, MI(Y;M)=0.976
# - Layer 6 upper: MI(X;M)=6.157, MI(Y;M)=0.974
# - Layer 7 upper: MI(X;M)=1.026, MI(Y;M)=0.950
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00006800
# - Layer 0 upper: MI(X;M)=11.992, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.475, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.319, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.394, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=6.950, MI(Y;M)=0.975
# - Layer 6 upper: MI(X;M)=6.159, MI(Y;M)=0.972
# - Layer 7 upper: MI(X;M)=1.026, MI(Y;M)=0.950
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00006900
# - Layer 0 upper: MI(X;M)=11.992, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.476, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.320, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.396, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=6.949, MI(Y;M)=0.974
# - Layer 6 upper: MI(X;M)=6.155, MI(Y;M)=0.971
# - Layer 7 upper: MI(X;M)=1.027, MI(Y;M)=0.950
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00007000
# - Layer 0 upper: MI(X;M)=11.992, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.881, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.476, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.321, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.396, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.949, MI(Y;M)=0.974
# - Layer 6 upper: MI(X;M)=6.140, MI(Y;M)=0.969
# - Layer 7 upper: MI(X;M)=1.025, MI(Y;M)=0.950
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00007100
# - Layer 0 upper: MI(X;M)=11.992, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.881, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.477, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.324, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.403, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=6.960, MI(Y;M)=0.974
# - Layer 6 upper: MI(X;M)=6.158, MI(Y;M)=0.970
# - Layer 7 upper: MI(X;M)=1.023, MI(Y;M)=0.950
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00007200
# - Layer 0 upper: MI(X;M)=11.993, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.476, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.323, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.403, MI(Y;M)=0.978
# - Layer 5 upper: MI(X;M)=6.957, MI(Y;M)=0.974
# - Layer 6 upper: MI(X;M)=6.150, MI(Y;M)=0.969
# - Layer 7 upper: MI(X;M)=1.023, MI(Y;M)=0.951
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00007300
# - Layer 0 upper: MI(X;M)=11.992, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.471, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.300, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.368, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.925, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=6.151, MI(Y;M)=0.968
# - Layer 7 upper: MI(X;M)=1.023, MI(Y;M)=0.948
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00007400
# - Layer 0 upper: MI(X;M)=11.992, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.471, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.303, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.375, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.927, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=6.149, MI(Y;M)=0.969
# - Layer 7 upper: MI(X;M)=1.022, MI(Y;M)=0.948
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00007500
# - Layer 0 upper: MI(X;M)=11.992, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.471, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.307, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.383, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.928, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=6.143, MI(Y;M)=0.970
# - Layer 7 upper: MI(X;M)=1.021, MI(Y;M)=0.947
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00007600
# - Layer 0 upper: MI(X;M)=11.993, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.472, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.310, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.389, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.935, MI(Y;M)=0.973
# - Layer 6 upper: MI(X;M)=6.141, MI(Y;M)=0.970
# - Layer 7 upper: MI(X;M)=1.021, MI(Y;M)=0.947
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00007700
# - Layer 0 upper: MI(X;M)=11.993, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.473, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.313, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.396, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.943, MI(Y;M)=0.974
# - Layer 6 upper: MI(X;M)=6.150, MI(Y;M)=0.971
# - Layer 7 upper: MI(X;M)=1.020, MI(Y;M)=0.947
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00007800
# - Layer 0 upper: MI(X;M)=11.993, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.473, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.315, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.402, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.950, MI(Y;M)=0.974
# - Layer 6 upper: MI(X;M)=6.154, MI(Y;M)=0.971
# - Layer 7 upper: MI(X;M)=1.020, MI(Y;M)=0.947
# Doing rawdata/relu_12-10-7-5-4-3-2/epoch00007900
# - Layer 0 upper: MI(X;M)=11.993, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.880, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.473, MI(Y;M)=0.994
# - Layer 3 upper: MI(X;M)=10.319, MI(Y;M)=0.992
# - Layer 4 upper: MI(X;M)=8.416, MI(Y;M)=0.977
# - Layer 5 upper: MI(X;M)=6.965, MI(Y;M)=0.974
# - Layer 6 upper: MI(X;M)=6.148, MI(Y;M)=0.970
# - Layer 7 upper: MI(X;M)=1.016, MI(Y;M)=0.945

# %% [markdown]
# Plot Infoplane Visualization
# ----

# %%
max_epoch = max( (max(vals.keys()) if len(vals) else 0) for vals in measures.values())
sm = plt.cm.ScalarMappable(cmap='gnuplot', norm=plt.Normalize(vmin=0, vmax=COLORBAR_MAX_EPOCHS))
sm._A = []

fig=plt.figure(figsize=(10,5))
for actndx, (activation, vals) in enumerate(measures.items()):
    epochs = sorted(vals.keys())
    if not len(epochs):
        continue
    plt.subplot(1,2,actndx+1)    
    for epoch in epochs:
        c = sm.to_rgba(epoch)
        xmvals = np.array(vals[epoch]['MI_XM_'+infoplane_measure])[PLOT_LAYERS]
        ymvals = np.array(vals[epoch]['MI_YM_'+infoplane_measure])[PLOT_LAYERS]

        plt.plot(xmvals, ymvals, c=c, alpha=0.1, zorder=1)
        plt.scatter(xmvals, ymvals, s=20, facecolors=[c for _ in PLOT_LAYERS], edgecolor='none', zorder=2)

    plt.ylim([0, 1])
    plt.xlim([0, 12])
#     plt.ylim([0, 3.5])
#     plt.xlim([0, 14])
    plt.xlabel('I(X;M)')
    plt.ylabel('I(Y;M)')
    plt.title(activation)
    
cbaxes = fig.add_axes([1.0, 0.125, 0.03, 0.8]) 
plt.colorbar(sm, label='Epoch', cax=cbaxes)
plt.tight_layout()

if DO_SAVE:
    plt.savefig('plots/' + DIR_TEMPLATE % ('infoplane_'+ARCH),bbox_inches='tight')
# Out:
# D:\anaconda\envs\keras\lib\site-packages\matplotlib\figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# Plot SNR curves
# ----

# %%
plt.figure(figsize=(12,5))

gs = gridspec.GridSpec(len(measures), len(PLOT_LAYERS))
for activation in measures.keys():
    cur_dir = 'rawdata/' + DIR_TEMPLATE % activation
    if not os.path.exists(cur_dir):
        continue
        
    epochs = []
    means = []
    stds = []
    wnorms = []
    for epochfile in sorted(os.listdir(cur_dir)):
        if not epochfile.startswith('epoch'):
            continue
            
        with open(cur_dir + "/"+epochfile, 'rb') as f:
            d = pickle.load(f)
            
        epoch = d['epoch']
        epochs.append(epoch)
        wnorms.append(d['data']['weights_norm'])
        means.append(d['data']['gradmean'])
        stds.append(d['data']['gradstd'])

    wnorms, means, stds = map(np.array, [wnorms, means, stds])
    for lndx,layerid in enumerate(PLOT_LAYERS):
        plt.subplot(gs[actndx, lndx])
        plt.plot(epochs, means[:,layerid], 'b', label="Mean")
        plt.plot(epochs, stds[:,layerid], 'orange', label="Std")
        plt.plot(epochs, means[:,layerid]/stds[:,layerid], 'red', label="SNR")
        plt.plot(epochs, wnorms[:,layerid], 'g', label="||W||")

        plt.title('Layer %d'%layerid)
        plt.xlabel('Epoch')
        plt.gca().set_xscale("log", nonposx='clip')
        plt.gca().set_yscale("log", nonposy='clip')
    

plt.legend(loc='lower left', bbox_to_anchor=(1.1, 0.2))
plt.tight_layout()

if DO_SAVE:
    plt.savefig('plots/' + DIR_TEMPLATE % ('snr_'+ARCH), bbox_inches='tight')
# Out:
# D:\anaconda\envs\keras\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# D:\anaconda\envs\keras\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# D:\anaconda\envs\keras\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# D:\anaconda\envs\keras\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# D:\anaconda\envs\keras\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# D:\anaconda\envs\keras\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# D:\anaconda\envs\keras\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# D:\anaconda\envs\keras\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
